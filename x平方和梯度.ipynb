# %% [markdown]
# # 实战

# %% [markdown]
# $$
# y = f(x) = x^2
# $$

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
x_plot = np.linspace(-10, 10, 400)
y_plot = torch.tensor(x_plot)**2

plt.plot(x_plot, y_plot)

plt.xlabel('x value')
plt.ylabel('f(x) value')
plt.title('Curve of Function y=x^2')
plt.show()

# %% [markdown]
# # 梯度

# %%
import torch

def sigmoid(x):
    return 1 / (1 + torch.exp(-x))

# %%
x1 = torch.tensor(0.0,requires_grad=True) 
x2 = torch.tensor(1.0, requires_grad=True)

def f(x1,x2):
    term1 = 3*sigmoid(x1 ** 2 +2 *x2+1)
    term2 = sigmoid(x1 ** 2 + 2 * x2+1)
    term3=1
    return sigmoid(term1 + term2 + term3)

# %%
 y = f(x1,x2)

# %%
y.backward()

# %%
print("x1 的梯度:",x1.grad)
print("x2 的梯度:",x2.grad)
# Out:
#   File "C:\Users\Administrator\AppData\Local\Temp\ipykernel_9568\3556226216.py", line 2
#     print("x2 的梯度:",x2.grad) x1的梯度:tensor(0.)
#                              ^
# SyntaxError: invalid syntax
